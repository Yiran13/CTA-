# %%
import numpy as np
import pandas as pd
from vnpy.app.cta_strategy.backtesting import BacktestingEngine, OptimizationSetting
from datetime import datetime
from market_stationary import MarketStationary
from trade_by_trade import (calculate_trades_result, generate_trade_df)

# %%
engine = BacktestingEngine()
engine.set_parameters(
    vt_symbol="IF888.CFFEX",
    interval="1m",
    start=datetime(2010, 10, 1),
    end=datetime(2018, 4, 30),
    rate=0.06/10000,
    slippage=0.2,
    size=300,
    pricetick=0.2,
    capital=1_000_000,
)
engine.add_strategy(MarketStationary, {'stationary_threshold':9/10000})

# %%
engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
# Out:
# 2020-04-16 16:50:22.748346	开始加载历史数据
# 2020-04-16 16:50:22.748346	加载进度： [1%]
# 2020-04-16 16:50:22.749308	加载进度： [2%]
# 2020-04-16 16:50:22.749308	加载进度： [3%]
# 2020-04-16 16:50:22.749308	加载进度： [4%]
# 2020-04-16 16:50:22.749308	加载进度： [5%]
# 2020-04-16 16:50:22.749308	加载进度： [7%]
# 2020-04-16 16:50:22.749308	加载进度： [8%]
# 2020-04-16 16:50:22.750343	加载进度： [9%]
# 2020-04-16 16:50:22.750343	加载进度： [10%]
# 2020-04-16 16:50:22.750343	加载进度：# [11%]
# 2020-04-16 16:50:22.750343	加载进度：# [12%]
# 2020-04-16 16:50:22.750343	加载进度：# [13%]
# 2020-04-16 16:50:22.751302	加载进度：# [14%]
# 2020-04-16 16:50:22.751302	加载进度：# [15%]
# 2020-04-16 16:50:22.751302	加载进度：# [16%]
# 2020-04-16 16:50:22.751302	加载进度：# [17%]
# 2020-04-16 16:50:22.751302	加载进度：# [18%]
# 2020-04-16 16:50:22.752337	加载进度：# [20%]
# 2020-04-16 16:50:22.752337	加载进度：## [21%]
# 2020-04-16 16:50:22.752337	加载进度：## [22%]
# 2020-04-16 16:50:22.752337	加载进度：## [23%]
# 2020-04-16 16:50:22.753303	加载进度：## [24%]
# 2020-04-16 16:50:22.753303	加载进度：## [25%]
# ...

# %%
engine.show_chart()
